# %%
import sys
import os

current = os.getcwd()
sys.path.append (current.replace('Scaleograms','LocalPackages'))

from contents import *

# %%
spectra = RamanSpectra('/Ploting/PR6S1E_01.txt',upLevels=1)

# %%
spectra.altPlot(xinit=200, xlim=3500)
