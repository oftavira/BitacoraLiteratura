# %%
from IPython.display import YouTubeVideo
YouTubeVideo('DKgqLmobFtc', width = 800, height= 500)

# %% [markdown]
# * #### Guide for style and other tools
#
# This notebook contains the [reference](https://medium.com/analytics-vidhya/the-jupyter-notebook-formatting-guide-873ab39f765e) for some utils when editing notebooks and some util videos and external references
#
# ***
#
#
#
#
# * #### Sparse representation by Steve Brunton
